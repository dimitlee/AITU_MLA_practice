# %% [markdown]
# # Data Manipulation with Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Categorical Types

# %% [markdown]
# * Pandas provides a convenient `dtype` for reprsenting categorical, or factor, data

# %%
c = pd.Categorical(['a', 'b', 'b', 'c', 'a', 'b', 'a', 'a', 'a', 'a'])

# %%
c
# Out:
# ['a', 'b', 'b', 'c', 'a', 'b', 'a', 'a', 'a', 'a']
# Categories (3, object): ['a', 'b', 'c']

# %%
c.describe()
# Out:
#             counts  freqs
# categories
# a                6    0.6
# b                3    0.3
# c                1    0.1

# %%
c.codes
# Out:
# array([0, 1, 1, 2, 0, 1, 0, 0, 0, 0], dtype=int8)

# %%
c.categories
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# * By default the Categorical type represents an **unordered categorical**
# * You can provide information about the order of categories

# %%
c.as_ordered()
# Out:
# ['a', 'b', 'b', 'c', 'a', 'b', 'a', 'a', 'a', 'a']
# Categories (3, object): ['a' < 'b' < 'c']

# %% [markdown]
# ### Support in DataFrames

# %% [markdown]
# * When a Categorical is in a DataFrame, there is a special `cat` accessor
# * This gives access to all of the features of the Categorical type

# %%
import numpy as np
dta = pd.DataFrame.from_dict({'factor': c,
                              'x': np.random.randn(10)})

# %%
dta.head()
# Out:
#   factor         x
# 0      a  1.055449
# 1      b  1.587205
# 2      b -0.112229
# 3      c  1.669506
# 4      a  0.671856

# %%
dta.dtypes
# Out:
# factor    category
# x          float64
# dtype: object

# %%
dta.factor.cat

# %%
dta.factor.cat.categories
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
dta.factor.describe()
# Out:
# count     10
# unique     3
# top        a
# freq       6
# Name: factor, dtype: object

# %% [markdown]
# ## Date and Time Types

# %% [markdown]
# Pandas provides conveniences for working with dates

# %% [markdown]
# ### Creating a Range of Dates

# %%
dates = pd.date_range("1/1/2015", periods=75, freq="D")
dates
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10', '2015-01-11', '2015-01-12',
#                '2015-01-13', '2015-01-14', '2015-01-15', '2015-01-16',
#                '2015-01-17', '2015-01-18', '2015-01-19', '2015-01-20',
#                '2015-01-21', '2015-01-22', '2015-01-23', '2015-01-24',
#                '2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31', '2015-02-01',
#                '2015-02-02', '2015-02-03', '2015-02-04', '2015-02-05',
#                '2015-02-06', '2015-02-07', '2015-02-08', '2015-02-09',
#                '2015-02-10', '2015-02-11', '2015-02-12', '2015-02-13',
#                '2015-02-14', '2015-02-15', '2015-02-16', '2015-02-17',
#                '2015-02-18', '2015-02-19', '2015-02-20', '2015-02-21',
#                '2015-02-22', '2015-02-23', '2015-02-24', '2015-02-25',
#                '2015-02-26', '2015-02-27', '2015-02-28', '2015-03-01',
#                '2015-03-02', '2015-03-03', '2015-03-04', '2015-03-05',
#                '2015-03-06', '2015-03-07', '2015-03-08', '2015-03-09',
#                '2015-03-10', '2015-03-11', '2015-03-12', '2015-03-13',
#                '2015-03-14', '2015-03-15', '2015-03-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
y = pd.Series(np.random.randn(75), index=dates)
y.head()
# Out:
# 2015-01-01   -1.028338
# 2015-01-02    0.338171
# 2015-01-03   -0.001185
# 2015-01-04   -0.736159
# 2015-01-05    2.099253
# Freq: D, dtype: float64

# %%
y.reset_index().dtypes
# Out:
# index    datetime64[ns]
# 0               float64
# dtype: object

# %% [markdown]
# ### Support in DataFrames

# %% [markdown]
# * When a `datetime` type is in a DataFrame, there is a special `dt` accessor
# * This gives access to all of the features of the datetime type

# %%
dta = (y.reset_index(name='t').
       rename(columns={'index': 'y'}))

# %%
dta.head()
# Out:
#            y         t
# 0 2015-01-01 -1.028338
# 1 2015-01-02  0.338171
# 2 2015-01-03 -0.001185
# 3 2015-01-04 -0.736159
# 4 2015-01-05  2.099253

# %%
dta.dtypes
# Out:
# y    datetime64[ns]
# t           float64
# dtype: object

# %%
dta.y.dt.freq
# Out:
# 'D'

# %%
dta.y.dt.day
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 70    12
# 71    13
# 72    14
# 73    15
# 74    16
# Name: y, Length: 75, dtype: int64

# %% [markdown]
# ### Indexing with Dates

# %% [markdown]
# * You can use strings
# * **Note**: the ending index is *inclusive* here. This is different than most of the rest of Python

# %%
y.loc["2015-01-01":"2015-01-15"]
# Out:
# 2015-01-01   -1.028338
# 2015-01-02    0.338171
# 2015-01-03   -0.001185
# 2015-01-04   -0.736159
# 2015-01-05    2.099253
# 2015-01-06   -0.554853
# 2015-01-07   -0.406214
# 2015-01-08    0.034154
# 2015-01-09   -0.982001
# 2015-01-10   -0.718087
# 2015-01-11   -0.964629
# 2015-01-12    2.512641
# 2015-01-13    1.556392
# 2015-01-14    0.693643
# 2015-01-15    0.785930
# Freq: D, dtype: float64

# %% [markdown]
# DatetimeIndex supports partial string indexing

# %%
y["2015-01"]
# Out:
# 2015-01-01   -1.028338
# 2015-01-02    0.338171
# 2015-01-03   -0.001185
# 2015-01-04   -0.736159
# 2015-01-05    2.099253
# 2015-01-06   -0.554853
# 2015-01-07   -0.406214
# 2015-01-08    0.034154
# 2015-01-09   -0.982001
# 2015-01-10   -0.718087
# 2015-01-11   -0.964629
# 2015-01-12    2.512641
# 2015-01-13    1.556392
# 2015-01-14    0.693643
# 2015-01-15    0.785930
# 2015-01-16    1.526950
# 2015-01-17    1.498832
# 2015-01-18    0.098307
# 2015-01-19   -0.742658
# 2015-01-20   -0.745786
# 2015-01-21   -0.049844
# 2015-01-22   -0.507006
# 2015-01-23    0.702688
# 2015-01-24    0.757892
# 2015-01-25    0.469493
# 2015-01-26   -1.038384
# 2015-01-27   -0.058840
# 2015-01-28   -1.288689
# 2015-01-29   -0.732362
# 2015-01-30   -0.834963
# 2015-01-31    0.903023
# Freq: D, dtype: float64

# %% [markdown]
# * You can **resample** to a lower frequency, specifying how to aggregate
# * Uses the `DateTeimIndexResampler` object

# %%
resample = y.resample("M")

# %%
resample.mean()
# Out:
# 2015-01-31    0.083464
# 2015-02-28   -0.181832
# 2015-03-31    0.288865
# Freq: M, dtype: float64

# %% [markdown]
# Or go to a higher frequency, optionally specifying how to fill in the

# %%
y.asfreq('H', method='ffill')
# Out:
# 2015-01-01 00:00:00   -1.028338
# 2015-01-01 01:00:00   -1.028338
# 2015-01-01 02:00:00   -1.028338
# 2015-01-01 03:00:00   -1.028338
# 2015-01-01 04:00:00   -1.028338
#                          ...
# 2015-03-15 20:00:00    0.647274
# 2015-03-15 21:00:00    0.647274
# 2015-03-15 22:00:00    0.647274
# 2015-03-15 23:00:00    0.647274
# 2015-03-16 00:00:00    0.947789
# Freq: H, Length: 1777, dtype: float64

# %% [markdown]
# There are convenience methods to lag and lead time series

# %%
y
# Out:
# 2015-01-01   -1.028338
# 2015-01-02    0.338171
# 2015-01-03   -0.001185
# 2015-01-04   -0.736159
# 2015-01-05    2.099253
#                 ...
# 2015-03-12    0.285625
# 2015-03-13    0.869701
# 2015-03-14    0.465625
# 2015-03-15    0.647274
# 2015-03-16    0.947789
# Freq: D, Length: 75, dtype: float64

# %%
y.shift(1)
# Out:
# 2015-01-01         NaN
# 2015-01-02   -1.028338
# 2015-01-03    0.338171
# 2015-01-04   -0.001185
# 2015-01-05   -0.736159
#                 ...
# 2015-03-12    0.996745
# 2015-03-13    0.285625
# 2015-03-14    0.869701
# 2015-03-15    0.465625
# 2015-03-16    0.647274
# Freq: D, Length: 75, dtype: float64

# %%
y.shift(-1)
# Out:
# 2015-01-01    0.338171
# 2015-01-02   -0.001185
# 2015-01-03   -0.736159
# 2015-01-04    2.099253
# 2015-01-05   -0.554853
#                 ...
# 2015-03-12    0.869701
# 2015-03-13    0.465625
# 2015-03-14    0.647274
# 2015-03-15    0.947789
# 2015-03-16         NaN
# Freq: D, Length: 75, dtype: float64

# %% [markdown]
# ### Rolling and Window Functions

# %% [markdown]
# * Pandas also provides a number of convenience functions for working on rolling or moving windows of time series through a common interface
# * This interface is the new **Rolling** object

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000',
                                                          periods=1000))
ts = ts.cumsum()

# %%
rolling = ts.rolling(window=60)
rolling
# Out:
# Rolling [window=60,center=False,axis=0,method=single]

# %%
rolling.mean()
# Out:
# 2000-01-01          NaN
# 2000-01-02          NaN
# 2000-01-03          NaN
# 2000-01-04          NaN
# 2000-01-05          NaN
#                 ...
# 2002-09-22   -43.973552
# 2002-09-23   -44.248433
# 2002-09-24   -44.521521
# 2002-09-25   -44.771426
# 2002-09-26   -45.026801
# Freq: D, Length: 1000, dtype: float64

# %% [markdown]
# ## Merging and Joining DataFrames

# %%
# this is a bit slow because of the date parsing

transit = pd.read_csv("sample_data/transit_segments.csv",
                      parse_dates=['st_time', 'end_time'],
                      infer_datetime_format=True)
vessels = pd.read_csv("sample_data/vessel_information.csv")

# %% [markdown]
# * A lot of the time data that comes from relational databases will be normalized
# * I.e., redundant information will be put in separate tables
# * Users are expected to *merge* or *join* tables to work with them

# %%
vessels.head()
# Out:
#    mmsi  num_names                                              names sov  \
# 0     1          8  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y
# 1     9          3                         000000009/Raven/Shearwater   N
# 2    21          1                                      Us Gov Vessel   Y
# 3    74          2                                  Mcfaul/Sarah Bell   N
# 4   103          3           Ron G/Us Navy Warship 103/Us Warship 103   Y
#
#       flag flag_type  num_loas                                    loa  \
# 0  Unknown   Unknown         7  42.0/48.0/57.0/90.0/138.0/154.0/156.0
# 1  Unknown   Unknown         2                              50.0/62.0
# 2  Unknown   Unknown         1                                  208.0
# 3  Unknown   Unknown         1                                  155.0
# 4  Unknown   Unknown         2                             26.0/155.0
#
#    max_loa  num_types                             type
# 0    156.0          4  Dredging/MilOps/Reserved/Towing
# 1     62.0          2                     Pleasure/Tug
# 2    208.0          1                          Unknown
# 3    155.0          1                          Unknown
# 4    155.0          2                   Tanker/Unknown

# %%
transit.head()
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
#
#    max_sog  pdgt10        st_time            end_time
# 0     14.5    96.5  2/10/09 16:03 2009-02-10 16:27:00
# 1     20.6   100.0   4/6/09 14:31 2009-04-06 15:20:00
# 2     20.5   100.0   4/6/09 14:36 2009-04-06 14:55:00
# 3     16.1   100.0  4/10/09 17:58 2009-04-10 18:34:00
# 4     16.2   100.0  4/10/09 17:59 2009-04-10 18:35:00

# %% [markdown]
# * Several ships in the vessels data have traveled multiple segments as we would expect
# * Matching the names in the transit data to the vessels data is thus a many-to-one match

# %% [markdown]
# * *aside* pandas Indices (of which Columns are one) are set-like

# %%
vessels.columns.intersection(transit.columns)
# Out:
# Index(['mmsi'], dtype='object')

# %% [markdown]
# ### Merging

# %% [markdown]
# * We can combine these two datasets for a many-to-one match
# * `merge` will use the common columns if we do not explicitly specify the columns

# %%
transit.merge(vessels).head()
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
#
#    max_sog  pdgt10        st_time  ... num_names  \
# 0     14.5    96.5  2/10/09 16:03  ...         8
# 1     20.6   100.0   4/6/09 14:31  ...         8
# 2     20.5   100.0   4/6/09 14:36  ...         8
# 3     16.1   100.0  4/10/09 17:58  ...         8
# 4     16.2   100.0  4/10/09 17:59  ...         8
#
#                                                names sov     flag flag_type  \
# 0  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown   Unknown
# 1  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown   Unknown
# 2  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown   Unknown
# 3  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown   Unknown
# 4  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown   Unknown
#
#   num_loas                                    loa max_loa  num_types  \
# 0        7  42.0/48.0/57.0/90.0/138.0/154.0/156.0   156.0          4
# 1        7  42.0/48.0/57.0/90.0/138.0/154.0/156.0   156.0          4
# 2        7  42.0/48.0/57.0/90.0/138.0/154.0/156.0   156.0          4
# 3        7  42.0/48.0/57.0/90.0/138.0/154.0/156.0   156.0          4
# 4        7  42.0/48.0/57.0/90.0/138.0/154.0/156.0   156.0          4
#
#                               type
# 0  Dredging/MilOps/Reserved/Towing
# 1  Dredging/MilOps/Reserved/Towing
# 2  Dredging/MilOps/Reserved/Towing
# 3  Dredging/MilOps/Reserved/Towing
# 4  Dredging/MilOps/Reserved/Towing
#
# [5 rows x 21 columns]

# %% [markdown]
# **Watch out**, when merging on columns, indices are discarded

# %%
A = pd.DataFrame(np.random.randn(25, 2),
                 index=pd.date_range('1/1/2015', periods=25))
A[2] = np.repeat(list('abcde'), 5)
A
# Out:
#                    0         1  2
# 2015-01-01  0.406887  2.117263  a
# 2015-01-02  0.813985  0.744858  a
# 2015-01-03 -0.062154  1.617545  a
# 2015-01-04  0.232155 -0.759728  a
# 2015-01-05 -0.858736  0.239402  a
# 2015-01-06 -1.119515 -1.722439  b
# 2015-01-07 -0.581288 -2.734204  b
# 2015-01-08  0.629382 -0.925939  b
# 2015-01-09 -0.839629  0.191023  b
# 2015-01-10 -0.097304 -0.812324  b
# 2015-01-11  0.656651  1.305285  c
# 2015-01-12  2.020164  0.589140  c
# 2015-01-13 -0.614392 -0.649672  c
# 2015-01-14 -0.243601  1.356707  c
# 2015-01-15  1.094956  0.631819  c
# 2015-01-16 -0.536799 -0.233300  d
# 2015-01-17  0.820981 -1.048194  d
# 2015-01-18  0.444164 -0.429484  d
# 2015-01-19 -0.593999  0.573071  d
# 2015-01-20  1.416433  0.069417  d
# 2015-01-21  0.894794  0.620918  e
# 2015-01-22 -0.973960  0.123944  e
# 2015-01-23 -0.453624  0.023138  e
# 2015-01-24 -3.691409 -0.030258  e
# 2015-01-25  0.831730  1.056064  e

# %%
B = pd.DataFrame(np.random.randn(5, 2))
B[2] = list('abcde')
B
# Out:
#           0         1  2
# 0 -0.226738  0.783186  a
# 1 -1.588627  0.979546  b
# 2  2.395403 -0.573645  c
# 3  0.748631  0.730317  d
# 4 -1.762566 -0.137184  e

# %%
A.merge(B, on=2)
# Out:
#          0_x       1_x  2       0_y       1_y
# 0   0.406887  2.117263  a -0.226738  0.783186
# 1   0.813985  0.744858  a -0.226738  0.783186
# 2  -0.062154  1.617545  a -0.226738  0.783186
# 3   0.232155 -0.759728  a -0.226738  0.783186
# 4  -0.858736  0.239402  a -0.226738  0.783186
# 5  -1.119515 -1.722439  b -1.588627  0.979546
# 6  -0.581288 -2.734204  b -1.588627  0.979546
# 7   0.629382 -0.925939  b -1.588627  0.979546
# 8  -0.839629  0.191023  b -1.588627  0.979546
# 9  -0.097304 -0.812324  b -1.588627  0.979546
# 10  0.656651  1.305285  c  2.395403 -0.573645
# 11  2.020164  0.589140  c  2.395403 -0.573645
# 12 -0.614392 -0.649672  c  2.395403 -0.573645
# 13 -0.243601  1.356707  c  2.395403 -0.573645
# 14  1.094956  0.631819  c  2.395403 -0.573645
# 15 -0.536799 -0.233300  d  0.748631  0.730317
# 16  0.820981 -1.048194  d  0.748631  0.730317
# 17  0.444164 -0.429484  d  0.748631  0.730317
# 18 -0.593999  0.573071  d  0.748631  0.730317
# 19  1.416433  0.069417  d  0.748631  0.730317
# 20  0.894794  0.620918  e -1.762566 -0.137184
# 21 -0.973960  0.123944  e -1.762566 -0.137184
# 22 -0.453624  0.023138  e -1.762566 -0.137184
# 23 -3.691409 -0.030258  e -1.762566 -0.137184
# 24  0.831730  1.056064  e -1.762566 -0.137184

# %% [markdown]
# ### Joins
#
# * Join is like merge, but it works on the indices
# * The same could be achieved with merge and the `left_index` and `right_index` keywords

# %%
transit.set_index('mmsi', inplace=True)
vessels.set_index('mmsi', inplace=True)

# %%
transit.join(vessels).head()
# Out:
#                    name  transit  segment  seg_length  avg_sog  min_sog  \
# mmsi
# 1           Us Govt Ves        1        1         5.1     13.2      9.2
# 1     Dredge Capt Frank        1        1        13.5     18.6     10.4
# 1         Us Gov Vessel        1        1         4.3     16.2     10.3
# 1         Us Gov Vessel        2        1         9.2     15.4     14.5
# 1     Dredge Capt Frank        2        1         9.2     15.4     14.6
#
#       max_sog  pdgt10        st_time            end_time  num_names  \
# mmsi
# 1        14.5    96.5  2/10/09 16:03 2009-02-10 16:27:00        8.0
# 1        20.6   100.0   4/6/09 14:31 2009-04-06 15:20:00        8.0
# 1        20.5   100.0   4/6/09 14:36 2009-04-06 14:55:00        8.0
# 1        16.1   100.0  4/10/09 17:58 2009-04-10 18:34:00        8.0
# 1        16.2   100.0  4/10/09 17:59 2009-04-10 18:35:00        8.0
#
#                                                   names sov     flag  \
# mmsi
# 1     Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown
# 1     Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown
# 1     Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown
# 1     Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown
# 1     Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y  Unknown
#
#      flag_type  num_loas                                    loa  max_loa  \
# mmsi
# 1      Unknown       7.0  42.0/48.0/57.0/90.0/138.0/154.0/156.0    156.0
# 1      Unknown       7.0  42.0/48.0/57.0/90.0/138.0/154.0/156.0    156.0
# 1      Unknown       7.0  42.0/48.0/57.0/90.0/138.0/154.0/156.0    156.0
# 1      Unknown       7.0  42.0/48.0/57.0/90.0/138.0/154.0/156.0    156.0
# 1      Unknown       7.0  42.0/48.0/57.0/90.0/138.0/154.0/156.0    156.0
#
#       num_types                             type
# mmsi
# 1           4.0  Dredging/MilOps/Reserved/Towing
# 1           4.0  Dredging/MilOps/Reserved/Towing
# 1           4.0  Dredging/MilOps/Reserved/Towing
# 1           4.0  Dredging/MilOps/Reserved/Towing
# 1           4.0  Dredging/MilOps/Reserved/Towing
